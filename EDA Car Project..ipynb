# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt     ##important libraries
import seaborn as sns

# %%
import warnings
warnings.filterwarnings('ignore')    ##supress warning

# %%
df=pd.read_csv("cars.csv")    ##that can read datasheet from downloaded file

# %%
df     ##show the datasheet
# Out:
#           Make       Model  Year                Engine Fuel Type  Engine HP  \
# 0          BMW  1 Series M  2011     premium unleaded (required)      335.0
# 1          BMW    1 Series  2011     premium unleaded (required)      300.0
# 2          BMW    1 Series  2011     premium unleaded (required)      300.0
# 3          BMW    1 Series  2011     premium unleaded (required)      230.0
# 4          BMW    1 Series  2011     premium unleaded (required)      230.0
# ...        ...         ...   ...                             ...        ...
# 11909    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11910    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11911    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11912    Acura         ZDX  2013  premium unleaded (recommended)      300.0
# 11913  Lincoln      Zephyr  2006                regular unleaded      221.0
#
# ...

# %%
df.head()        #by default first 5 data are printed include rows and columns
# Out:
#   Make       Model  Year             Engine Fuel Type  Engine HP  \
# 0  BMW  1 Series M  2011  premium unleaded (required)      335.0
# 1  BMW    1 Series  2011  premium unleaded (required)      300.0
# 2  BMW    1 Series  2011  premium unleaded (required)      300.0
# 3  BMW    1 Series  2011  premium unleaded (required)      230.0
# 4  BMW    1 Series  2011  premium unleaded (required)      230.0
#
#    Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# 0               6.0            MANUAL  rear wheel drive              2.0
# 1               6.0            MANUAL  rear wheel drive              2.0
# 2               6.0            MANUAL  rear wheel drive              2.0
# 3               6.0            MANUAL  rear wheel drive              2.0
# 4               6.0            MANUAL  rear wheel drive              2.0
#
#                          Market Category Vehicle Size Vehicle Style  \
# ...

# %%
df.head(10) #first 10 rows and columns
# Out:
#   Make       Model  Year             Engine Fuel Type  Engine HP  \
# 0  BMW  1 Series M  2011  premium unleaded (required)      335.0
# 1  BMW    1 Series  2011  premium unleaded (required)      300.0
# 2  BMW    1 Series  2011  premium unleaded (required)      300.0
# 3  BMW    1 Series  2011  premium unleaded (required)      230.0
# 4  BMW    1 Series  2011  premium unleaded (required)      230.0
# 5  BMW    1 Series  2012  premium unleaded (required)      230.0
# 6  BMW    1 Series  2012  premium unleaded (required)      300.0
# 7  BMW    1 Series  2012  premium unleaded (required)      300.0
# 8  BMW    1 Series  2012  premium unleaded (required)      230.0
# 9  BMW    1 Series  2013  premium unleaded (required)      230.0
#
#    Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# 0               6.0            MANUAL  rear wheel drive              2.0
# 1               6.0            MANUAL  rear wheel drive              2.0
# ...

# %%
df.tail()  #by default last 5 data includes raws and columns
# Out:
#           Make   Model  Year                Engine Fuel Type  Engine HP  \
# 11909    Acura     ZDX  2012     premium unleaded (required)      300.0
# 11910    Acura     ZDX  2012     premium unleaded (required)      300.0
# 11911    Acura     ZDX  2012     premium unleaded (required)      300.0
# 11912    Acura     ZDX  2013  premium unleaded (recommended)      300.0
# 11913  Lincoln  Zephyr  2006                regular unleaded      221.0
#
#        Engine Cylinders Transmission Type      Driven_Wheels  Number of Doors  \
# 11909               6.0         AUTOMATIC    all wheel drive              4.0
# 11910               6.0         AUTOMATIC    all wheel drive              4.0
# 11911               6.0         AUTOMATIC    all wheel drive              4.0
# 11912               6.0         AUTOMATIC    all wheel drive              4.0
# 11913               6.0         AUTOMATIC  front wheel drive              4.0
#
# ...

# %%
df.tail(10) #last 10 data include row and column
# Out:
#           Make   Model  Year                Engine Fuel Type  Engine HP  \
# 11904      BMW      Z8  2002     premium unleaded (required)      394.0
# 11905      BMW      Z8  2003     premium unleaded (required)      394.0
# 11906    Acura     ZDX  2011     premium unleaded (required)      300.0
# 11907    Acura     ZDX  2011     premium unleaded (required)      300.0
# 11908    Acura     ZDX  2011     premium unleaded (required)      300.0
# 11909    Acura     ZDX  2012     premium unleaded (required)      300.0
# 11910    Acura     ZDX  2012     premium unleaded (required)      300.0
# 11911    Acura     ZDX  2012     premium unleaded (required)      300.0
# 11912    Acura     ZDX  2013  premium unleaded (recommended)      300.0
# 11913  Lincoln  Zephyr  2006                regular unleaded      221.0
#
#        Engine Cylinders Transmission Type      Driven_Wheels  Number of Doors  \
# 11904               8.0            MANUAL   rear wheel drive              2.0
# ...

# %%
df.sample()  #randomly one sample
# Out:
#         Make  Model  Year  Engine Fuel Type  Engine HP  Engine Cylinders  \
# 1309  Suzuki  Aerio  2005  regular unleaded      155.0               4.0
#
#      Transmission Type      Driven_Wheels  Number of Doors Market Category  \
# 1309         AUTOMATIC  front wheel drive              4.0             NaN
#
#      Vehicle Size Vehicle Style  highway MPG  city mpg  Popularity   MSRP
# 1309      Compact         Sedan           28        22         481  16049

# %%
df.sample(5) #randomly 5 sample printed
# Out:
#           Make        Model  Year  Engine Fuel Type  Engine HP  \
# 4918      Ford     Freestar  2005  regular unleaded        NaN
# 9323       GMC  Sierra 1500  2015  regular unleaded      355.0
# 2561     Honda        Civic  2015  regular unleaded      143.0
# 6960   Pontiac      Montana  2005  regular unleaded      200.0
# 10310    Scion           tC  2014  regular unleaded      179.0
#
#        Engine Cylinders Transmission Type      Driven_Wheels  Number of Doors  \
# 4918                6.0         AUTOMATIC  front wheel drive              4.0
# 9323                8.0         AUTOMATIC   four wheel drive              4.0
# 2561                4.0         AUTOMATIC  front wheel drive              2.0
# 6960                6.0         AUTOMATIC  front wheel drive              4.0
# 10310               4.0            MANUAL  front wheel drive              2.0
#
#       Market Category Vehicle Size      Vehicle Style  highway MPG  city mpg  \
# ...

# %%
df.info()  ##to show information of data sheet
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11914 entries, 0 to 11913
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Make               11914 non-null  object
#  1   Model              11914 non-null  object
#  2   Year               11914 non-null  int64
#  3   Engine Fuel Type   11911 non-null  object
#  4   Engine HP          11845 non-null  float64
#  5   Engine Cylinders   11884 non-null  float64
#  6   Transmission Type  11914 non-null  object
#  7   Driven_Wheels      11914 non-null  object
#  8   Number of Doors    11908 non-null  float64
#  9   Market Category    8172 non-null   object
#  10  Vehicle Size       11914 non-null  object
#  11  Vehicle Style      11914 non-null  object
#  12  highway MPG        11914 non-null  int64
#  13  city mpg           11914 non-null  int64
#  14  Popularity         11914 non-null  int64
#  15  MSRP               11914 non-null  int64
# ...

# %%
df.isnull()  #is used to detect missing values for an array-like object.
# Out:
#         Make  Model   Year  Engine Fuel Type  Engine HP  Engine Cylinders  \
# 0      False  False  False             False      False             False
# 1      False  False  False             False      False             False
# 2      False  False  False             False      False             False
# 3      False  False  False             False      False             False
# 4      False  False  False             False      False             False
# ...      ...    ...    ...               ...        ...               ...
# 11909  False  False  False             False      False             False
# 11910  False  False  False             False      False             False
# 11911  False  False  False             False      False             False
# 11912  False  False  False             False      False             False
# 11913  False  False  False             False      False             False
#
#        Transmission Type  Driven_Wheels  Number of Doors  Market Category  \
# ...

# %%
df.isnull().sum()
# Out:
# Make                    0
# Model                   0
# Year                    0
# Engine Fuel Type        3
# Engine HP              69
# Engine Cylinders       30
# Transmission Type       0
# Driven_Wheels           0
# Number of Doors         6
# Market Category      3742
# Vehicle Size            0
# Vehicle Style           0
# highway MPG             0
# city mpg                0
# Popularity              0
# MSRP                    0
# dtype: int64

# %%
df.isnull().sum().sort_values(ascending=False)  #arrange the data set on ascending order
# Out:
# Market Category      3742
# Engine HP              69
# Engine Cylinders       30
# Number of Doors         6
# Engine Fuel Type        3
# Make                    0
# Model                   0
# Year                    0
# Transmission Type       0
# Driven_Wheels           0
# Vehicle Size            0
# Vehicle Style           0
# highway MPG             0
# city mpg                0
# Popularity              0
# MSRP                    0
# dtype: int64

# %%
df.dtypes
# Out:
# Make                  object
# Model                 object
# Year                   int64
# Engine Fuel Type      object
# Engine HP            float64
# Engine Cylinders     float64
# Transmission Type     object
# Driven_Wheels         object
# Number of Doors      float64
# Market Category       object
# Vehicle Size          object
# Vehicle Style         object
# highway MPG            int64
# city mpg               int64
# Popularity             int64
# MSRP                   int64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11914 entries, 0 to 11913
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Make               11914 non-null  object
#  1   Model              11914 non-null  object
#  2   Year               11914 non-null  int64
#  3   Engine Fuel Type   11911 non-null  object
#  4   Engine HP          11845 non-null  float64
#  5   Engine Cylinders   11884 non-null  float64
#  6   Transmission Type  11914 non-null  object
#  7   Driven_Wheels      11914 non-null  object
#  8   Number of Doors    11908 non-null  float64
#  9   Market Category    8172 non-null   object
#  10  Vehicle Size       11914 non-null  object
#  11  Vehicle Style      11914 non-null  object
#  12  highway MPG        11914 non-null  int64
#  13  city mpg           11914 non-null  int64
#  14  Popularity         11914 non-null  int64
#  15  MSRP               11914 non-null  int64
# ...

# %%
df.isnull().sum()
# Out:
# Make                    0
# Model                   0
# Year                    0
# Engine Fuel Type        3
# Engine HP              69
# Engine Cylinders       30
# Transmission Type       0
# Driven_Wheels           0
# Number of Doors         6
# Market Category      3742
# Vehicle Size            0
# Vehicle Style           0
# highway MPG             0
# city mpg                0
# Popularity              0
# MSRP                    0
# dtype: int64

# %% [markdown]
# # Engine HP

# %%
df[df['Engine HP'].isnull()]
# Out:
#          Make        Model  Year                Engine Fuel Type  Engine HP  \
# 539      FIAT         500e  2015                        electric        NaN
# 540      FIAT         500e  2016                        electric        NaN
# 541      FIAT         500e  2017                        electric        NaN
# 2905  Lincoln  Continental  2017  premium unleaded (recommended)        NaN
# 2906  Lincoln  Continental  2017  premium unleaded (recommended)        NaN
# ...       ...          ...   ...                             ...        ...
# 9850      Kia      Soul EV  2015                        electric        NaN
# 9851      Kia      Soul EV  2015                        electric        NaN
# 9852      Kia      Soul EV  2016                        electric        NaN
# 9853      Kia      Soul EV  2016                        electric        NaN
# 9854      Kia      Soul EV  2016                        electric        NaN
#
# ...

# %%
df['Engine HP']
# Out:
# 0        335.0
# 1        300.0
# 2        300.0
# 3        230.0
# 4        230.0
#          ...
# 11909    300.0
# 11910    300.0
# 11911    300.0
# 11912    300.0
# 11913    221.0
# Name: Engine HP, Length: 11914, dtype: float64

# %%
df.describe()['Engine HP']
# Out:
# count    11845.00000
# mean       249.38607
# std        109.19187
# min         55.00000
# 25%        170.00000
# 50%        227.00000
# 75%        300.00000
# max       1001.00000
# Name: Engine HP, dtype: float64

# %%
df['Engine HP'].fillna(int(df['Engine HP'].mean()),inplace=True)

# %%
df
# Out:
#           Make       Model  Year                Engine Fuel Type  Engine HP  \
# 0          BMW  1 Series M  2011     premium unleaded (required)      335.0
# 1          BMW    1 Series  2011     premium unleaded (required)      300.0
# 2          BMW    1 Series  2011     premium unleaded (required)      300.0
# 3          BMW    1 Series  2011     premium unleaded (required)      230.0
# 4          BMW    1 Series  2011     premium unleaded (required)      230.0
# ...        ...         ...   ...                             ...        ...
# 11909    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11910    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11911    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11912    Acura         ZDX  2013  premium unleaded (recommended)      300.0
# 11913  Lincoln      Zephyr  2006                regular unleaded      221.0
#
# ...

# %% [markdown]
# # observation

# %% [markdown]
# - There are 69 rows have null values
# - mean is 249.38 and 50% percentile is 227.00000 which is nearest to mean

# %% [markdown]
# # Engine Cylinders

# %%
df[df['Engine Cylinders'].isnull()]
# Out:
#             Make    Model  Year             Engine Fuel Type  Engine HP  \
# 1983   Chevrolet  Bolt EV  2017                     electric      200.0
# 1984   Chevrolet  Bolt EV  2017                     electric      200.0
# 3716  Volkswagen   e-Golf  2015                     electric      115.0
# 3717  Volkswagen   e-Golf  2015                     electric      115.0
# 3718  Volkswagen   e-Golf  2016                     electric      115.0
# 3719  Volkswagen   e-Golf  2016                     electric      115.0
# 5778  Mitsubishi   i-MiEV  2014                     electric      249.0
# 5779  Mitsubishi   i-MiEV  2016                     electric       66.0
# 5780  Mitsubishi   i-MiEV  2017                     electric       66.0
# 8373      Toyota  RAV4 EV  2012                     electric      154.0
# 8695       Mazda     RX-7  1993             regular unleaded      255.0
# 8696       Mazda     RX-7  1994             regular unleaded      255.0
# ...

# %%
df['Engine Cylinders']
# Out:
# 0        6.0
# 1        6.0
# 2        6.0
# 3        6.0
# 4        6.0
#         ...
# 11909    6.0
# 11910    6.0
# 11911    6.0
# 11912    6.0
# 11913    6.0
# Name: Engine Cylinders, Length: 11914, dtype: float64

# %%
df.describe()['Engine Cylinders']
# Out:
# count    11884.000000
# mean         5.628829
# std          1.780559
# min          0.000000
# 25%          4.000000
# 50%          6.000000
# 75%          6.000000
# max         16.000000
# Name: Engine Cylinders, dtype: float64

# %%
df['Engine Cylinders'].fillna(int(df['Engine Cylinders'].mean()),inplace=True)

# %%
df
# Out:
#           Make       Model  Year                Engine Fuel Type  Engine HP  \
# 0          BMW  1 Series M  2011     premium unleaded (required)      335.0
# 1          BMW    1 Series  2011     premium unleaded (required)      300.0
# 2          BMW    1 Series  2011     premium unleaded (required)      300.0
# 3          BMW    1 Series  2011     premium unleaded (required)      230.0
# 4          BMW    1 Series  2011     premium unleaded (required)      230.0
# ...        ...         ...   ...                             ...        ...
# 11909    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11910    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11911    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11912    Acura         ZDX  2013  premium unleaded (recommended)      300.0
# 11913  Lincoln      Zephyr  2006                regular unleaded      221.0
#
# ...

# %% [markdown]
# # observation

# %% [markdown]
# - There are 30 rows have null values
# - mean is 5.6 and 50% percentile is 6.0 which is nearest to mean

# %% [markdown]
# # Engine Fuel Type

# %%
df[df['Engine Fuel Type'].isnull()]
# Out:
#          Make   Model  Year Engine Fuel Type  Engine HP  Engine Cylinders  \
# 11321  Suzuki  Verona  2004              NaN      155.0               6.0
# 11322  Suzuki  Verona  2004              NaN      155.0               6.0
# 11323  Suzuki  Verona  2004              NaN      155.0               6.0
#
#       Transmission Type      Driven_Wheels  Number of Doors Market Category  \
# 11321         AUTOMATIC  front wheel drive              4.0             NaN
# 11322         AUTOMATIC  front wheel drive              4.0             NaN
# 11323         AUTOMATIC  front wheel drive              4.0             NaN
#
#       Vehicle Size Vehicle Style  highway MPG  city mpg  Popularity   MSRP
# 11321      Midsize         Sedan           25        17         481  17199
# 11322      Midsize         Sedan           25        17         481  20199
# 11323      Midsize         Sedan           25        17         481  18499

# %%
df['Engine Fuel Type']
# Out:
# 0           premium unleaded (required)
# 1           premium unleaded (required)
# 2           premium unleaded (required)
# 3           premium unleaded (required)
# 4           premium unleaded (required)
#                       ...
# 11909       premium unleaded (required)
# 11910       premium unleaded (required)
# 11911       premium unleaded (required)
# 11912    premium unleaded (recommended)
# 11913                  regular unleaded
# Name: Engine Fuel Type, Length: 11914, dtype: object

# %%
md=df['Engine Fuel Type'].mode()
print(md)
# Out:
# 0    regular unleaded
# dtype: object

# %%
print(md[0])
# Out:
# regular unleaded

# %%
df['Engine Fuel Type']=df['Engine Fuel Type'].fillna(md[0])
df
# Out:
#           Make       Model  Year                Engine Fuel Type  Engine HP  \
# 0          BMW  1 Series M  2011     premium unleaded (required)      335.0
# 1          BMW    1 Series  2011     premium unleaded (required)      300.0
# 2          BMW    1 Series  2011     premium unleaded (required)      300.0
# 3          BMW    1 Series  2011     premium unleaded (required)      230.0
# 4          BMW    1 Series  2011     premium unleaded (required)      230.0
# ...        ...         ...   ...                             ...        ...
# 11909    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11910    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11911    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11912    Acura         ZDX  2013  premium unleaded (recommended)      300.0
# 11913  Lincoln      Zephyr  2006                regular unleaded      221.0
#
# ...

# %%
df.isnull().sum()
# Out:
# Make                    0
# Model                   0
# Year                    0
# Engine Fuel Type        0
# Engine HP               0
# Engine Cylinders        0
# Transmission Type       0
# Driven_Wheels           0
# Number of Doors         6
# Market Category      3742
# Vehicle Size            0
# Vehicle Style           0
# highway MPG             0
# city mpg                0
# Popularity              0
# MSRP                    0
# dtype: int64

# %% [markdown]
# # observation

# %% [raw]
# - There are 3 rows have null values
# - this column is categorical so we can use mode

# %% [markdown]
# #Number of Doors

# %%
df[df['Number of Doors'].isnull()]
# Out:
#          Make    Model  Year             Engine Fuel Type  Engine HP  \
# 4666  Ferrari       FF  2013  premium unleaded (required)      651.0
# 6930    Tesla  Model S  2016                     electric      249.0
# 6931    Tesla  Model S  2016                     electric      249.0
# 6932    Tesla  Model S  2016                     electric      249.0
# 6933    Tesla  Model S  2016                     electric      249.0
# 6934    Tesla  Model S  2016                     electric      249.0
#
#       Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# 4666              12.0  AUTOMATED_MANUAL   all wheel drive              NaN
# 6930               0.0      DIRECT_DRIVE   all wheel drive              NaN
# 6931               0.0      DIRECT_DRIVE   all wheel drive              NaN
# 6932               0.0      DIRECT_DRIVE   all wheel drive              NaN
# 6933               0.0      DIRECT_DRIVE  rear wheel drive              NaN
# ...

# %%
df['Number of Doors']
# Out:
# 0        2.0
# 1        2.0
# 2        2.0
# 3        2.0
# 4        2.0
#         ...
# 11909    4.0
# 11910    4.0
# 11911    4.0
# 11912    4.0
# 11913    4.0
# Name: Number of Doors, Length: 11914, dtype: float64

# %%
df.describe()['Number of Doors']
# Out:
# count    11908.000000
# mean         3.436093
# std          0.881315
# min          2.000000
# 25%          2.000000
# 50%          4.000000
# 75%          4.000000
# max          4.000000
# Name: Number of Doors, dtype: float64

# %%
df['Number of Doors'].fillna(int(df['Number of Doors'].mean()),inplace=True)

# %%
df
# Out:
#           Make       Model  Year                Engine Fuel Type  Engine HP  \
# 0          BMW  1 Series M  2011     premium unleaded (required)      335.0
# 1          BMW    1 Series  2011     premium unleaded (required)      300.0
# 2          BMW    1 Series  2011     premium unleaded (required)      300.0
# 3          BMW    1 Series  2011     premium unleaded (required)      230.0
# 4          BMW    1 Series  2011     premium unleaded (required)      230.0
# ...        ...         ...   ...                             ...        ...
# 11909    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11910    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11911    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11912    Acura         ZDX  2013  premium unleaded (recommended)      300.0
# 11913  Lincoln      Zephyr  2006                regular unleaded      221.0
#
# ...

# %% [markdown]
# # observation
# -mean is 3.4 and 50% percentile is 4 which is nearest to mean

# %% [markdown]
# # market category

# %%
df[df['Market Category'].isnull()]
# Out:
#          Make     Model  Year                Engine Fuel Type  Engine HP  \
# 87     Nissan     200SX  1996                regular unleaded      115.0
# 88     Nissan     200SX  1996                regular unleaded      115.0
# 91     Nissan     200SX  1997                regular unleaded      115.0
# 92     Nissan     200SX  1997                regular unleaded      115.0
# 93     Nissan     200SX  1998                regular unleaded      115.0
# ...       ...       ...   ...                             ...        ...
# 11794  Subaru        XT  1991                regular unleaded      145.0
# 11809  Toyota  Yaris iA  2017                regular unleaded      106.0
# 11810  Toyota  Yaris iA  2017                regular unleaded      106.0
# 11867     GMC     Yukon  2015  premium unleaded (recommended)      420.0
# 11868     GMC     Yukon  2015  premium unleaded (recommended)      420.0
#
#        Engine Cylinders Transmission Type      Driven_Wheels  Number of Doors  \
# ...

# %%
df.describe()
# Out:
#                Year     Engine HP  Engine Cylinders  Number of Doors  \
# count  11914.000000  11914.000000      11914.000000     11914.000000
# mean    2010.384338    249.383834          5.627245         3.435874
# std        7.579740    108.875196          1.778595         0.881148
# min     1990.000000     55.000000          0.000000         2.000000
# 25%     2007.000000    170.000000          4.000000         2.000000
# 50%     2015.000000    227.000000          6.000000         4.000000
# 75%     2016.000000    300.000000          6.000000         4.000000
# max     2017.000000   1001.000000         16.000000         4.000000
#
#         highway MPG      city mpg    Popularity          MSRP
# count  11914.000000  11914.000000  11914.000000  1.191400e+04
# mean      26.637485     19.733255   1554.911197  4.059474e+04
# std        8.863001      8.987798   1441.855347  6.010910e+04
# min       12.000000      7.000000      2.000000  2.000000e+03
# ...

# %%
df['Market Category'].mode()
# Out:
# 0    Crossover
# dtype: object

# %%
df['Market Category'].fillna(df['Market Category'].mode()[0],inplace=True)

# %%
df
# Out:
#           Make       Model  Year                Engine Fuel Type  Engine HP  \
# 0          BMW  1 Series M  2011     premium unleaded (required)      335.0
# 1          BMW    1 Series  2011     premium unleaded (required)      300.0
# 2          BMW    1 Series  2011     premium unleaded (required)      300.0
# 3          BMW    1 Series  2011     premium unleaded (required)      230.0
# 4          BMW    1 Series  2011     premium unleaded (required)      230.0
# ...        ...         ...   ...                             ...        ...
# 11909    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11910    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11911    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11912    Acura         ZDX  2013  premium unleaded (recommended)      300.0
# 11913  Lincoln      Zephyr  2006                regular unleaded      221.0
#
# ...

# %% [markdown]
# # observation
# There are 3742 rows have null values

# %%
df.isnull().sum()
# Out:
# Make                 0
# Model                0
# Year                 0
# Engine Fuel Type     0
# Engine HP            0
# Engine Cylinders     0
# Transmission Type    0
# Driven_Wheels        0
# Number of Doors      0
# Market Category      0
# Vehicle Size         0
# Vehicle Style        0
# highway MPG          0
# city mpg             0
# Popularity           0
# MSRP                 0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11914 entries, 0 to 11913
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Make               11914 non-null  object
#  1   Model              11914 non-null  object
#  2   Year               11914 non-null  int64
#  3   Engine Fuel Type   11914 non-null  object
#  4   Engine HP          11914 non-null  float64
#  5   Engine Cylinders   11914 non-null  float64
#  6   Transmission Type  11914 non-null  object
#  7   Driven_Wheels      11914 non-null  object
#  8   Number of Doors    11914 non-null  float64
#  9   Market Category    11914 non-null  object
#  10  Vehicle Size       11914 non-null  object
#  11  Vehicle Style      11914 non-null  object
#  12  highway MPG        11914 non-null  int64
#  13  city mpg           11914 non-null  int64
#  14  Popularity         11914 non-null  int64
#  15  MSRP               11914 non-null  int64
# ...

# %%
df['Year']=df['Year'].astype(float)

# %%
df['Year']
# Out:
# 0        2011.0
# 1        2011.0
# 2        2011.0
# 3        2011.0
# 4        2011.0
#           ...
# 11909    2012.0
# 11910    2012.0
# 11911    2012.0
# 11912    2013.0
# 11913    2006.0
# Name: Year, Length: 11914, dtype: float64

# %%
df['highway MPG']=df['highway MPG'].astype(float)

# %%
df['highway MPG']
# Out:
# 0        26.0
# 1        28.0
# 2        28.0
# 3        28.0
# 4        28.0
#          ...
# 11909    23.0
# 11910    23.0
# 11911    23.0
# 11912    23.0
# 11913    26.0
# Name: highway MPG, Length: 11914, dtype: float64

# %%
df['city mpg']=df['city mpg'].astype(float)

# %%
df['city mpg']
# Out:
# 0        19.0
# 1        19.0
# 2        20.0
# 3        18.0
# 4        18.0
#          ...
# 11909    16.0
# 11910    16.0
# 11911    16.0
# 11912    16.0
# 11913    17.0
# Name: city mpg, Length: 11914, dtype: float64

# %%
df['Popularity']=df['Popularity'].astype(float)

# %%
df['Popularity']
# Out:
# 0        3916.0
# 1        3916.0
# 2        3916.0
# 3        3916.0
# 4        3916.0
#           ...
# 11909     204.0
# 11910     204.0
# 11911     204.0
# 11912     204.0
# 11913      61.0
# Name: Popularity, Length: 11914, dtype: float64

# %%
df['MSRP']=df['MSRP'].astype(float)

# %%
df['MSRP']
# Out:
# 0        46135.0
# 1        40650.0
# 2        36350.0
# 3        29450.0
# 4        34500.0
#           ...
# 11909    46120.0
# 11910    56670.0
# 11911    50620.0
# 11912    50920.0
# 11913    28995.0
# Name: MSRP, Length: 11914, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11914 entries, 0 to 11913
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Make               11914 non-null  object
#  1   Model              11914 non-null  object
#  2   Year               11914 non-null  float64
#  3   Engine Fuel Type   11914 non-null  object
#  4   Engine HP          11914 non-null  float64
#  5   Engine Cylinders   11914 non-null  float64
#  6   Transmission Type  11914 non-null  object
#  7   Driven_Wheels      11914 non-null  object
#  8   Number of Doors    11914 non-null  float64
#  9   Market Category    11914 non-null  object
#  10  Vehicle Size       11914 non-null  object
#  11  Vehicle Style      11914 non-null  object
#  12  highway MPG        11914 non-null  float64
#  13  city mpg           11914 non-null  float64
#  14  Popularity         11914 non-null  float64
# ...

# %% [markdown]
# # check outliers

# %%
df.skew()
# Out:
# Year                -1.221981
# Engine HP            1.295046
# Engine Cylinders     0.967864
# Number of Doors     -0.968049
# highway MPG          7.573931
# city mpg             7.106681
# Popularity           1.653443
# MSRP                11.771987
# dtype: float64

# %% [markdown]
# # year

# %%
plt.figure(figsize= (16,5))
plt.subplot(1,2,1)
sns.displot(df['Year'])
plt.show()

# %% [markdown]
# # Capping Outliers

# %%
cap=np.percentile(df['Year'],99) #YEAR
print(cap)
# Out:
# 2017.0

# %%
df['Year']=df['Year'].apply(lambda x: x if x <2017.0 else 2017.0)

# %%
plt.boxplot(df['Year'])
plt.show()

# %%
cap=np.percentile(df['Engine HP'],99) #ENGINE HP
print(cap)
# Out:
# 620.0

# %%
df['Engine HP']=df['Engine HP'].apply(lambda x: x if x <2017.0 else 2017.0)

# %%
plt.boxplot(df['Year'])
plt.show()

# %%
cap=np.percentile(df['Engine Cylinders'],99) #Engine Cylinders
print(cap)
# Out:
# 12.0

# %%
df['Engine HP']=df['Engine HP'].apply(lambda x: x if x <12.0 else 12.0)

# %%
plt.boxplot(df['Year'])
plt.show()

# %%
cap=np.percentile(df['Number of Doors'],99) # Number of Doors 
print(cap)
# Out:
# 4.0

# %%
df['Number of Doors']=df['Number of Doors'].apply(lambda x: x if x <4.0 else 4.0)

# %%
plt.boxplot(df['Number of Doors'])
plt.show()

# %%
cap=np.percentile(df['highway MPG'],99) # highway mpg
print(cap)
# Out:
# 46.0

# %%
df['highway MPG']=df['highway MPG'].apply(lambda x: x if x <46.0 else 46.0)

# %%
plt.boxplot(df['highway MPG'])
plt.show()

# %%
cap=np.percentile(df['city mpg'],99) #city mpg
print(cap)
# Out:
# 44.0

# %%
df['city mpg']=df['city mpg'].apply(lambda x: x if x <44.0 else 44.0)

# %%
plt.boxplot(df['city mpg'])
plt.show()

# %%
cap=np.percentile(df['Popularity'],99) #Popularity
print(cap)
# Out:
# 5657.0

# %%
df['Popularity']=df['Popularity'].apply(lambda x: x if x <5657.0 else 5657.0)

# %%
plt.boxplot(df['city mpg'])
plt.show()

# %%
cap=np.percentile(df['MSRP'],99) #MSRP
print(cap)
# Out:
# 284488.1200000005

# %%
df['MSRP']=df['MSRP'].apply(lambda x: x if x <284488.12 else 284488.12)

# %%
plt.boxplot(df['MSRP'])
plt.show()

# %% [markdown]
# # BOXPLOT

# %%
df.boxplot(column=['Year'])
plt.show()

# %%
df.boxplot(column=['Engine HP'])
plt.show()

# %%
df.boxplot(column=['Engine Cylinders'])
plt.show()

# %%
df.boxplot(column=['highway MPG'])
plt.show()

# %%
df.boxplot(column=['city mpg'])
plt.show()

# %%
df.boxplot(column=['Popularity'])
plt.show()

# %%
df.boxplot(column=['Number of Doors'])
plt.show()

# %%
df.boxplot(column=['MSRP'])
sns.displot(df['MSRP']
# Out:
#   File "<ipython-input-91-6cbf74e443cc>", line 2
#     sns.displot(df['MSRP']
#                           ^
# SyntaxError: unexpected EOF while parsing

# %% [markdown]
# # DISPLOT

# %%
df['Year'].describe()
sns.displot(df['Year'])
plt.show()

# %%
df['Engine HP'].describe()
sns.displot(df['Year'])
plt.show()

# %%
df['Engine Cylinders'].describe()
sns.displot(df['Year'])
plt.show()

# %%
df['Number of Doors'].describe()
sns.displot(df['Year'])
plt.show()

# %%
df['highway MPG'].describe()
sns.displot(df['highway MPG'])
plt.show()

# %%
df['city mpg'].describe()
sns.displot(df['city mpg'])
plt.show()

# %%
df['Popularity'].describe()
sns.displot(df['Popularity'])
plt.show()

# %%
df['MSRP'].describe()
sns.displot(df['MSRP'])
plt.show()

# %% [markdown]
# # Byvariet Analysis
# # scatter polt

# %%
plt.scatter(df.Year,df.MSRP)
plt.show()

# %%
plt.scatter(df.Year,df.MSRP,alpha=0.2,s=50,c='purple')

# %% [markdown]
# # Joint plot

# %%
sns.jointplot(df.Year,df.Popularity)
plt.show()

# %% [markdown]
# # side by side box plot

# %%
sns.boxplot(data=df,x='Popularity',y='Make')
plt.show()

# %%
sns.boxplot(data=df,x='Year',y='Model')
plt.show()

# %%
sns.boxplot(data=df,x='Popularity',y='Engine Fuel Type')
plt.show()

# %% [markdown]
# # pairplot

# %%
sns.pairplot(df[['Year', 'Engine HP', 'Engine Cylinders', 'Number of Doors', 'highway MPG', 'city mpg', 'Popularity', 'MSRP']])
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# # heat map

# %%
cor1 = df.corr()

# %%
sns.heatmap(cor1,annot=True)
plt.show()
